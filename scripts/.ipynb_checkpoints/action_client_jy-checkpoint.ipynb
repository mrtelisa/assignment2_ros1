# %%
import rospy
import actionlib
from geometry_msgs.msg import PoseStamped

from nav_msgs.msg import Odometry 
from sensor_msgs.msg import LaserScan 
from std_msgs.msg import Header

from IPython.display import display
from ipywidgets import IntText, Button, HBox, VBox, Label

import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %matplotlib notebook

import assignment_2_2024.msg
# Out:
# [ERROR] [1746547988.174700, 1273.664000]: bad callback: <function scan_callback at 0x7f338c59d5e0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.220425, 1273.692000]: bad callback: <function odom_callback at 0x7f338f66caf0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.222816, 1273.707000]: bad callback: <function scan_callback at 0x7f338c59d790>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.225833, 1273.708000]: bad callback: <function odom_callback at 0x7f338c59d4c0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.239556, 1273.719000]: bad callback: <function scan_callback at 0x7f338f66cb80>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.241092, 1273.719000]: bad callback: <function odom_callback at 0x7f338c59d820>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.257922, 1273.728000]: bad callback: <function scan_callback at 0x7f338c59d5e0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.279415, 1273.752000]: bad callback: <function odom_callback at 0x7f338f66caf0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.287280, 1273.753000]: bad callback: <function odom_callback at 0x7f338c59d4c0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.288835, 1273.753000]: bad callback: <function scan_callback at 0x7f338c59d790>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.307400, 1273.780000]: bad callback: <function odom_callback at 0x7f338c59d820>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.312081, 1273.782000]: bad callback: <function scan_callback at 0x7f338f66cb80>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.318441, 1273.785000]: bad callback: <function scan_callback at 0x7f338c59d5e0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.324582, 1273.788000]: bad callback: <function odom_callback at 0x7f338f66caf0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.337920, 1273.797000]: bad callback: <function scan_callback at 0x7f338c59d790>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.341393, 1273.805000]: bad callback: <function odom_callback at 0x7f338c59d4c0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.345586, 1273.808000]: bad callback: <function odom_callback at 0x7f338c59d820>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.360627, 1273.822000]: bad callback: <function scan_callback at 0x7f338f66cb80>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.367796, 1273.829000]: bad callback: <function scan_callback at 0x7f338c59d5e0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.370402, 1273.834000]: bad callback: <function odom_callback at 0x7f338f66caf0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.374625, 1273.836000]: bad callback: <function scan_callback at 0x7f338c59d790>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.380751, 1273.843000]: bad callback: <function odom_callback at 0x7f338c59d4c0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.388495, 1273.847000]: bad callback: <function scan_callback at 0x7f338f66cb80>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.399373, 1273.851000]: bad callback: <function odom_callback at 0x7f338c59d820>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.405349, 1273.862000]: bad callback: <function scan_callback at 0x7f338c59d5e0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.414614, 1273.872000]: bad callback: <function scan_callback at 0x7f338c59d790>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.421599, 1273.877000]: bad callback: <function scan_callback at 0x7f338f66cb80>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.425183, 1273.878000]: bad callback: <function odom_callback at 0x7f338f66caf0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.439033, 1273.878000]: bad callback: <function scan_callback at 0x7f338c59d5e0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
# [ERROR] [1746547988.455883, 1273.909000]: bad callback: <function odom_callback at 0x7f338c59d4c0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.466041, 1273.914000]: bad callback: <function scan_callback at 0x7f338c59d790>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.477454, 1273.924000]: bad callback: <function scan_callback at 0x7f338f66cb80>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.482462, 1273.924000]: bad callback: <function odom_callback at 0x7f338c59d820>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.506679, 1273.936000]: bad callback: <function scan_callback at 0x7f338c59d5e0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.508480, 1273.937000]: bad callback: <function odom_callback at 0x7f338f66caf0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.524299, 1273.953000]: bad callback: <function scan_callback at 0x7f338c59d790>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.535973, 1273.964000]: bad callback: <function odom_callback at 0x7f338c59d4c0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.543159, 1273.973000]: bad callback: <function scan_callback at 0x7f338f66cb80>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.574645, 1273.986000]: bad callback: <function odom_callback at 0x7f338c59d820>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.578053, 1273.990000]: bad callback: <function scan_callback at 0x7f338c59d5e0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.601274, 1274.027000]: bad callback: <function odom_callback at 0x7f338f66caf0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.609156, 1274.037000]: bad callback: <function scan_callback at 0x7f338c59d790>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.614202, 1274.041000]: bad callback: <function odom_callback at 0x7f338c59d4c0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.618647, 1274.044000]: bad callback: <function scan_callback at 0x7f338f66cb80>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.627019, 1274.057000]: bad callback: <function odom_callback at 0x7f338c59d820>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.639982, 1274.065000]: bad callback: <function scan_callback at 0x7f338c59d5e0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.641825, 1274.065000]: bad callback: <function odom_callback at 0x7f338f66caf0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.645731, 1274.073000]: bad callback: <function scan_callback at 0x7f338c59d790>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.652006, 1274.076000]: bad callback: <function odom_callback at 0x7f338c59d4c0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
# [ERROR] [1746547988.663493, 1274.085000]: bad callback: <function scan_callback at 0x7f338f66cb80>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.689040, 1274.097000]: bad callback: <function odom_callback at 0x7f338c59d820>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.693976, 1274.110000]: bad callback: <function scan_callback at 0x7f338c59d5e0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.703032, 1274.119000]: bad callback: <function odom_callback at 0x7f338f66caf0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.710309, 1274.126000]: bad callback: <function scan_callback at 0x7f338c59d790>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.715519, 1274.127000]: bad callback: <function odom_callback at 0x7f338c59d4c0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.727452, 1274.133000]: bad callback: <function scan_callback at 0x7f338f66cb80>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.734559, 1274.141000]: bad callback: <function odom_callback at 0x7f338c59d820>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.752044, 1274.153000]: bad callback: <function scan_callback at 0x7f338c59d5e0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.755970, 1274.153000]: bad callback: <function odom_callback at 0x7f338f66caf0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.766671, 1274.168000]: bad callback: <function scan_callback at 0x7f338c59d790>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.770390, 1274.168000]: bad callback: <function odom_callback at 0x7f338c59d4c0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.778213, 1274.182000]: bad callback: <function scan_callback at 0x7f338f66cb80>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.782310, 1274.184000]: bad callback: <function odom_callback at 0x7f338c59d820>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.809289, 1274.211000]: bad callback: <function odom_callback at 0x7f338f66caf0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.811015, 1274.211000]: bad callback: <function scan_callback at 0x7f338c59d5e0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.823592, 1274.221000]: bad callback: <function odom_callback at 0x7f338c59d4c0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.830641, 1274.227000]: bad callback: <function scan_callback at 0x7f338c59d790>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.836288, 1274.234000]: bad callback: <function odom_callback at 0x7f338c59d820>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.853818, 1274.250000]: bad callback: <function scan_callback at 0x7f338f66cb80>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.857336, 1274.251000]: bad callback: <function odom_callback at 0x7f338f66caf0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
# [ERROR] [1746547988.873224, 1274.267000]: bad callback: <function scan_callback at 0x7f338c59d5e0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.876610, 1274.270000]: bad callback: <function odom_callback at 0x7f338c59d4c0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.880218, 1274.270000]: bad callback: <function scan_callback at 0x7f338c59d790>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.887405, 1274.281000]: bad callback: <function odom_callback at 0x7f338c59d820>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.904033, 1274.294000]: bad callback: <function scan_callback at 0x7f338f66cb80>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.905510, 1274.297000]: bad callback: <function odom_callback at 0x7f338f66caf0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.910787, 1274.300000]: bad callback: <function scan_callback at 0x7f338c59d5e0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.927212, 1274.317000]: bad callback: <function odom_callback at 0x7f338c59d4c0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.932880, 1274.322000]: bad callback: <function scan_callback at 0x7f338c59d790>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.942694, 1274.329000]: bad callback: <function odom_callback at 0x7f338c59d820>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.946270, 1274.330000]: bad callback: <function scan_callback at 0x7f338f66cb80>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.967417, 1274.342000]: bad callback: <function scan_callback at 0x7f338c59d5e0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.973943, 1274.347000]: bad callback: <function odom_callback at 0x7f338f66caf0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.981573, 1274.352000]: bad callback: <function scan_callback at 0x7f338c59d790>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547988.987726, 1274.358000]: bad callback: <function odom_callback at 0x7f338c59d4c0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547988.995077, 1274.363000]: bad callback: <function scan_callback at 0x7f338f66cb80>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547989.003125, 1274.369000]: bad callback: <function odom_callback at 0x7f338c59d820>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547989.012536, 1274.378000]: bad callback: <function scan_callback at 0x7f338c59d5e0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547989.019275, 1274.382000]: bad callback: <function odom_callback at 0x7f338f66caf0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547989.028146, 1274.393000]: bad callback: <function scan_callback at 0x7f338c59d790>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547989.032928, 1274.393000]: bad callback: <function odom_callback at 0x7f338c59d4c0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547989.037907, 1274.399000]: bad callback: <function scan_callback at 0x7f338f66cb80>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547989.051592, 1274.401000]: bad callback: <function odom_callback at 0x7f338c59d820>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547989.063866, 1274.407000]: bad callback: <function scan_callback at 0x7f338c59d5e0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
# [ERROR] [1746547989.079848, 1274.430000]: bad callback: <function scan_callback at 0x7f338c59d790>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547989.083663, 1274.433000]: bad callback: <function odom_callback at 0x7f338f66caf0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547989.109030, 1274.447000]: bad callback: <function scan_callback at 0x7f338f66cb80>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547989.113898, 1274.453000]: bad callback: <function odom_callback at 0x7f338c59d4c0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547989.121258, 1274.465000]: bad callback: <function odom_callback at 0x7f338c59d820>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547989.128216, 1274.468000]: bad callback: <function scan_callback at 0x7f338c59d5e0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547989.140573, 1274.477000]: bad callback: <function scan_callback at 0x7f338c59d790>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547989.144973, 1274.483000]: bad callback: <function odom_callback at 0x7f338f66caf0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547989.152013, 1274.491000]: bad callback: <function scan_callback at 0x7f338f66cb80>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547989.157877, 1274.496000]: bad callback: <function odom_callback at 0x7f338c59d4c0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547989.161850, 1274.496000]: bad callback: <function scan_callback at 0x7f338c59d5e0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547989.165025, 1274.496000]: bad callback: <function odom_callback at 0x7f338c59d820>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547989.183686, 1274.517000]: bad callback: <function scan_callback at 0x7f338c59d790>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547989.199064, 1274.533000]: bad callback: <function odom_callback at 0x7f338f66caf0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547989.202263, 1274.535000]: bad callback: <function scan_callback at 0x7f338f66cb80>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547989.205726, 1274.538000]: bad callback: <function odom_callback at 0x7f338c59d4c0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746547989.217418, 1274.550000]: bad callback: <function scan_callback at 0x7f338c59d5e0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746547989.218647, 1274.550000]: bad callback: <function odom_callback at 0x7f338c59d820>
# Traceback (most recent call last):
# ...
#
# [ERROR] [1746548045.614936, 1318.678000]: bad callback: <function scan_callback at 0x7f338f66cb80>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746548045.622871, 1318.686000]: bad callback: <function odom_callback at 0x7f338f66caf0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746548045.631440, 1318.696000]: bad callback: <function scan_callback at 0x7f338c59d5e0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746548045.636099, 1318.700000]: bad callback: <function odom_callback at 0x7f338c59d4c0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746548045.643310, 1318.705000]: bad callback: <function odom_callback at 0x7f338c59d820>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746548045.649005, 1318.706000]: bad callback: <function scan_callback at 0x7f338c59d790>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746548045.658634, 1318.718000]: bad callback: <function scan_callback at 0x7f338f66cb80>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746548045.665241, 1318.725000]: bad callback: <function scan_callback at 0x7f338c59d5e0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
# [ERROR] [1746548045.678251, 1318.730000]: bad callback: <function odom_callback at 0x7f338f66caf0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746548045.686013, 1318.743000]: bad callback: <function scan_callback at 0x7f338c59d790>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746548045.690417, 1318.752000]: bad callback: <function odom_callback at 0x7f338c59d4c0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746548045.694778, 1318.755000]: bad callback: <function odom_callback at 0x7f338c59d820>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746548045.707890, 1318.761000]: bad callback: <function scan_callback at 0x7f338f66cb80>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746548045.714942, 1318.761000]: bad callback: <function scan_callback at 0x7f338c59d5e0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746548045.726065, 1318.770000]: bad callback: <function scan_callback at 0x7f338c59d790>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746548045.739154, 1318.781000]: bad callback: <function scan_callback at 0x7f338f66cb80>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746548045.742749, 1318.785000]: bad callback: <function odom_callback at 0x7f338f66caf0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746548045.752084, 1318.789000]: bad callback: <function odom_callback at 0x7f338c59d4c0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746548045.754091, 1318.790000]: bad callback: <function scan_callback at 0x7f338c59d5e0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746548045.760065, 1318.799000]: bad callback: <function odom_callback at 0x7f338c59d820>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746548045.767068, 1318.804000]: bad callback: <function scan_callback at 0x7f338c59d790>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746548045.782447, 1318.818000]: bad callback: <function scan_callback at 0x7f338f66cb80>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746548045.788293, 1318.822000]: bad callback: <function scan_callback at 0x7f338c59d5e0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746548045.799893, 1318.834000]: bad callback: <function odom_callback at 0x7f338f66caf0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746548045.801059, 1318.834000]: bad callback: <function scan_callback at 0x7f338c59d790>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746548045.805784, 1318.839000]: bad callback: <function odom_callback at 0x7f338c59d4c0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746548045.810890, 1318.840000]: bad callback: <function odom_callback at 0x7f338c59d820>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746548045.827720, 1318.862000]: bad callback: <function scan_callback at 0x7f338f66cb80>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746548045.832567, 1318.866000]: bad callback: <function scan_callback at 0x7f338c59d5e0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746548045.840140, 1318.875000]: bad callback: <function scan_callback at 0x7f338c59d790>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746548045.846355, 1318.881000]: bad callback: <function scan_callback at 0x7f338f66cb80>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746548045.848968, 1318.883000]: bad callback: <function odom_callback at 0x7f338f66caf0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746548045.860987, 1318.888000]: bad callback: <function odom_callback at 0x7f338c59d4c0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746548045.863059, 1318.889000]: bad callback: <function scan_callback at 0x7f338c59d5e0>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746548045.866966, 1318.892000]: bad callback: <function odom_callback at 0x7f338c59d820>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 8, in odom_callback
#     position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"
# NameError: name 'position_label' is not defined
#
# [ERROR] [1746548045.871649, 1318.897000]: bad callback: <function scan_callback at 0x7f338c59d790>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined
#
# [ERROR] [1746548045.882941, 1318.907000]: bad callback: <function scan_callback at 0x7f338f66cb80>
# Traceback (most recent call last):
#   File "/opt/ros/noetic/lib/python3/dist-packages/rospy/topics.py", line 750, in _invoke_callback
#     cb(msg)
#   File "/tmp/ipykernel_73283/2648536370.py", line 19, in scan_callback
#     obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"
# NameError: name 'obstacle_label' is not defined

# %%
# Initializing the ROS node
if not rospy.core.is_initialized():
    rospy.init_node('jupyter_client_node', anonymous=True)

# Creating the action client
client = actionlib.SimpleActionClient('reaching_goal', assignment_2_2024.msg.PlanningAction)
client.wait_for_server()

current_feedback = None 

robot_position = (0.0, 0.0) 
obstacle_dist = float('inf') 

# Arrays to memorize the trajectory
traj_x = []
traj_y = []

# Adding labels to print status, position and distance from obstacles
status_label = Label(value = "")
position_label = Label(value="Robot position: (0.00, 0.00)")
obstacle_label = Label(value="Closest obstacle: N/A")

# %%
# Function for odom acallback
def odom_callback(msg): 
    global robot_position, traj_x, traj_y
    x =  msg.pose.pose.position.x
    y =  msg.pose.pose.position.y
    robot_position = (x, y)

    position_label.value = f"Robot position: ({x:.2f}, {y:.2f})"

    traj_x.append(x)
    traj_y.append(y)

# Function to distance callback
def scan_callback(msg):
    global obstacle_dist
    dist = [d for d in msg.ranges if not rospy.is_shutdown() and msg.range_min < d < msg.range_max]
    if dist:
        obstacle_dist = min(dist)
        obstacle_label.value = f"Closest obstacle: {obstacle_dist:.2f} m"  

# Creating two subscribers to the two topics
rospy.Subscriber("/odom", Odometry, odom_callback)
rospy.Subscriber("/scan", LaserScan, scan_callback)

# %%
# Function to update feedback
def update_feedback(fd): 
    global current_feedback
    current_feedback = fd
    
# Function to set and send the goal
def send_goal(b):
    x = x_input.value
    y = y_input.value

    if(-10.0 < x < 10.0 and -10 < y < 10.0):
        goal = assignment_2_2024.msg.PlanningGoal()
        goal.target_pose = PoseStamped()

        goal.target_pose.header.stamp = rospy.Time.now()
        goal.target_pose.header.frame_id = "odom"
        goal.target_pose.pose.orientation.w = 1.0

        goal.target_pose.pose.position.x = x
        goal.target_pose.pose.position.y = y
                
        client.send_goal(goal, feedback_cb = update_feedback)

        rospy.sleep(0.5)
        state = client.get_state()
        rospy.loginfo(f"Goal status: {state}")

        rospy.loginfo(f"Goal sent: ({x}, {y})")
        status_label.value = f"Goal sent: ({x}, {y})"
        
    else:
        rospy.loginfo("Target out of boundaries")        
        status_label.value = "Target out of boundaries"


# Function to delete the goal
def cancel_goal(b):
    client.cancel_goal()
    rospy.loginfo("Goal cancelled")
    status_label.value = "Goal cancelled"

# %%
# Function the cancel button activate 
def cancel_goal_btn(b):
    if client.get_state() not in [actionlib.GoalStatus.SUCCEEDED, actionlib.GoalStatus.ABORTED, actionlib.GoalStatus.PREEMPTED]:
        rospy.loginfo("Cancelling the current goal.")
        client.cancel_goal()
    else:
        rospy.loginfo("The goal has already been achieved.")

# Function the feedback button activate 
def update_feedback_btn(b):
    rospy.loginfo("Requesting feedback...\n")
    if current_feedback is None:
        rospy.loginfo("No feedback has been recieved")
        status_label.value = "No feedback has been recieved"
    else:
        rospy.loginfo(f"Latest feedback:\n {current_feedback}")
        status_label.value = f"Latest feedback:\n {current_feedback}"

# %%
# Function to update the robot position graph
def update_graph(frame):
    ax.clear()
    ax.plot(traj_x, traj_y, 'b-', label = 'Trajectory')
    ax.plot(traj_x[-1], traj_y[-1], 'ro', label = 'Current Position')
    ax.set_xlim(-10, 10)
    ax.set_ylim(-10, 10)
    ax.set_title('Robot Position in real-time')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.legend()
    ax.grid(True)

# %%
# UI widgets
x_input = IntText(value = 0, description =  'X: ')
y_input = IntText(value = 0, description =  'Y: ')

send_btn = Button(description = "Send Goal", button_style = 'success')
cancel_btn = Button(description = "Cancel Goal", button_style = 'danger')
feedback_btn = Button(description = "FeedBack")

send_btn.on_click(send_goal)
cancel_btn.on_click(cancel_goal_btn)
feedback_btn.on_click(update_feedback_btn)

# Layout
ui = VBox ([
    HBox([x_input, y_input]),
    HBox([send_btn, cancel_btn]),
    HBox([feedback_btn]),
    status_label,
    position_label,
    obstacle_label
])

display(ui)

fig, ax = plt.subplots(figsize = (6,6))
ani = FuncAnimation(fig, update_graph, interval = 1000)

# display(fig)
# Out:
# VBox(children=(HBox(children=(IntText(value=0, description='X: '), IntText(value=0, description='Y: '))), HBox…
# <img src="data:image/png;base64,..." width="600">
# [INFO] [1746547065.893738, 1246.008000]: Goal sent: (4, 7)
# [INFO] [1746547117.692652, 1288.956000]: Cancelling the current goal.
# [INFO] [1746547123.326285, 1293.639000]: Goal sent: (2, 2)
